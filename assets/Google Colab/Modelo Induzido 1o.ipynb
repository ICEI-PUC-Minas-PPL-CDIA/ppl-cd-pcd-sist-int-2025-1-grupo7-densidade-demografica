# %% [markdown]
# # Importar as bibliotecas e funções

# %%
import sklearn as sk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report # type: ignore
from sklearn import tree
from yellowbrick.classifier import ConfusionMatrix # type: ignore

# %% [markdown]
# # Ler a base

# %%
df = pd.read_csv('Filtragem_Transformada(3).csv')
df
# Out:
#                                     Id  Idade Faixa idade     Gênero  \
# 0     001b2d1qtli8t9z7oqgdhj001b2d4i0g     31       30-34  Masculino
# 1     0026aa3fwd78u0026asg7456tfkjg2cs     30       30-34  Masculino
# 2     00r21rb9pusd1b0v7ew00r21rw3dy69w     37       35-39   Feminino
# 3     00v0az4g792svil00vn6y1kfm9hq8vy9     34       30-34  Masculino
# 4     015qqbrh4rr015qje9gvkbsb7ti1n5df     30       30-34  Masculino
# ...                                ...    ...         ...        ...
# 2902  zwm2c16e32000c6iaswzwm2c1jv6swo0     36       35-39   Feminino
# 2903  zws1zie6ro3he9ln337yufzws1zyj7nw     23       22-24  Masculino
# 2904  zxvrsh0xk8z95k76e63zxvrshjgyigq0     27       25-29   Feminino
# 2905  zy7hsey7pigk6d4a4zy7hsm7bh1vcozc     28       25-29  Masculino
# 2906  zyppgxzxko25qkgwsbrgpzyppgxzxs81     32       30-34  Masculino
#
#      Cor/raca/etnia  PCD  Vive no Brasil          Estado onde mora  \
# 0            Branca    0               1         Minas Gerais (MG)
# 1            Branca    0               1       Espírito Santo (ES)
# 2           Amarela    0               1            São Paulo (SP)
# 3            Branca    0               1         Minas Gerais (MG)
# 4            Branca    0               1       Rio de Janeiro (RJ)
# ...             ...  ...             ...                       ...
# 2902          Parda    0               1            São Paulo (SP)
# 2903          Parda    0               1                Goiás (GO)
# 2904          Parda    0               1       Espírito Santo (ES)
# 2905         Branca    0               1            São Paulo (SP)
# 2906         Branca    0               1  Rio Grande do Norte (RN)
#
#      UF onde mora Região onde Mora  ... Qual sua situação atual de trabalho?  \
# 0              MG          Sudeste  ...                      Empregado (CLT)
# 1              ES          Sudeste  ...     Empreendedor ou Empregado (CNPJ)
# 2              SP          Sudeste  ...                      Empregado (CLT)
# 3              MG          Sudeste  ...     Empreendedor ou Empregado (CNPJ)
# 4              RJ          Sudeste  ...     Empreendedor ou Empregado (CNPJ)
# ...           ...              ...  ...                                  ...
# 2902           SP          Sudeste  ...                      Empregado (CLT)
# 2903           GO     Centro-oeste  ...                      Empregado (CLT)
# 2904           ES          Sudeste  ...                      Empregado (CLT)
# 2905           SP          Sudeste  ...                      Empregado (CLT)
# 2906           RN         Nordeste  ...                      Empregado (CLT)
#
#                                Setor Numero de Funcionários  \
# 0                 Finanças ou Bancos         Acima de 3.000
# 1                 Finanças ou Bancos           de 101 a 500
# 2                 Finanças ou Bancos         Acima de 3.000
# 3                        Outra Opção           de 101 a 500
# 4     Tecnologia/Fábrica de Software            de 51 a 100
# ...                              ...                    ...
# 2902                   Área da Saúde           de 101 a 500
# 2903                          Varejo            de 51 a 100
# 2904                          Varejo         Acima de 3.000
# 2905              Finanças ou Bancos         de 501 a 1.000
# 2906                     Outra Opção         Acima de 3.000
#
#                                             Cargo Atual   Nível  \
# 0                     Cientista de Dados/Data Scientist  Sênior
# 1                             Analista de BI/BI Analyst   Pleno
# 2                        Analista de Dados/Data Analyst  Júnior
# 3                        Analista de Dados/Data Analyst  Júnior
# 4     Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# ...                                                 ...     ...
# 2902                     Analista de Dados/Data Analyst   Pleno
# 2903                     Analista de Dados/Data Analyst  Júnior
# 2904  Data Product Manager/ Product Manager (PM/APM/...   Pleno
# 2905                  Cientista de Dados/Data Scientist  Júnior
# 2906  Engenheiro de Machine Learning/ML Engineer/AI ...   Pleno
#
#                         Faixa salarial  \
# 0     de R$ 12.001/mês a R$ 16.000/mês
# 1       de R$ 6.001/mês a R$ 8.000/mês
# 2       de R$ 6.001/mês a R$ 8.000/mês
# 3       de R$ 4.001/mês a R$ 6.000/mês
# 4      de R$ 8.001/mês a R$ 12.000/mês
# ...                                ...
# 2902    de R$ 6.001/mês a R$ 8.000/mês
# 2903    de R$ 3.001/mês a R$ 4.000/mês
# 2904   de R$ 8.001/mês a R$ 12.000/mês
# 2905   de R$ 8.001/mês a R$ 12.000/mês
# 2906   de R$ 8.001/mês a R$ 12.000/mês
#
#      Quanto tempo de experiência na área de dados você tem?  \
# 0                                         de 3 a 4 anos
# 1                                         de 3 a 4 anos
# 2                                         de 1 a 2 anos
# 3                                        Menos de 1 ano
# 4                                         de 1 a 2 anos
# ...                                                 ...
# 2902                                      de 3 a 4 anos
# 2903                                     Menos de 1 ano
# 2904                                      de 3 a 4 anos
# 2905                                      de 1 a 2 anos
# 2906                                      de 4 a 6 anos
#
#      Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0     Não tive experiência na área de TI/Engenharia ...
# 1                                         de 3 a 4 anos
# 2                                        Menos de 1 ano
# 3                                        Menos de 1 ano
# 4     Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 2902  Não tive experiência na área de TI/Engenharia ...
# 2903                                      de 3 a 4 anos
# 2904  Não tive experiência na área de TI/Engenharia ...
# 2905  Não tive experiência na área de TI/Engenharia ...
# 2906  Não tive experiência na área de TI/Engenharia ...
#
#      Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 2902                                                  0
# 2903                                                  0
# 2904                                                  0
# 2905                                                  0
# 2906                                                  0
#
#      Existe faculdade no Estado
# 0                             1
# 1                             0
# 2                             1
# 3                             1
# 4                             0
# ...                         ...
# 2902                          1
# 2903                          0
# 2904                          0
# 2905                          1
# 2906                          0
#
# [2907 rows x 22 columns]

# %%
df.dtypes
# Out:
# Id                                                                                                                           object
# Idade                                                                                                                         int64
# Faixa idade                                                                                                                  object
# Gênero                                                                                                                       object
# Cor/raca/etnia                                                                                                               object
# PCD                                                                                                                           int64
# Vive no Brasil                                                                                                                int64
# Estado onde mora                                                                                                             object
# UF onde mora                                                                                                                 object
# Região onde Mora                                                                                                             object
# Nível de Ensino                                                                                                              object
# Área de Formação                                                                                                             object
# Qual sua situação atual de trabalho?                                                                                         object
# Setor                                                                                                                        object
# Numero de Funcionários                                                                                                       object
# Cargo Atual                                                                                                                  object
# Nível                                                                                                                        object
# Faixa salarial                                                                                                               object
# Quanto tempo de experiência na área de dados você tem?                                                                       object
# Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?    object
# Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?                                                  int64
# Existe faculdade no Estado                                                                                                    int64
# dtype: object

# %% [markdown]
# ## Retiração das colunas Região e Estado onde mora

# %%
df = df.drop(['Região onde Mora'], axis = 'columns')
df = df.drop(['Estado onde mora'], axis = 'columns')

# %% [markdown]
# ## Dropando coluna inútil

# %%
df = df.drop(['Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?'], axis = 'columns')
df = df.drop(['Numero de Funcionários'], axis = 'columns')
df = df.drop(['Qual sua situação atual de trabalho?'], axis = 'columns')

# %% [markdown]
# ## Transformação dos gêneros em 0s e 1s
#
# Masculino == 0
# Feminino == 1

# %%
df['Gênero'] = df['Gênero'].replace({'Masculino': 0, 'Feminino': 1})
df['Gênero'] = df['Gênero'].replace({'Outro': 0, 'Prefiro não informar': 0})
# Out:
# <ipython-input-9-a884458a2b61>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gênero'] = df['Gênero'].replace({'Outro': 0, 'Prefiro não informar': 0})

# %% [markdown]
# ## Transformação dos dados em ordem alfabética

# %%
df['Id'] = LabelEncoder().fit_transform(df['Id'])
df['Faixa idade'] = LabelEncoder().fit_transform(df['Faixa idade'])
df['UF onde mora'] = LabelEncoder().fit_transform(df['UF onde mora'])
df['Área de Formação'] = LabelEncoder().fit_transform(df['Área de Formação'])
df['Setor'] = LabelEncoder().fit_transform(df['Setor'])
df['Cargo Atual'] = LabelEncoder().fit_transform(df['Cargo Atual'])
df['Faixa salarial'] = LabelEncoder().fit_transform(df['Faixa salarial'])
df['Quanto tempo de experiência na área de dados você tem?'] = LabelEncoder().fit_transform(df['Quanto tempo de experiência na área de dados você tem?'])
df['Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?'] = LabelEncoder().fit_transform(df['Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?'])
df['Cor/raca/etnia'] = LabelEncoder().fit_transform(df['Cor/raca/etnia'])

# %% [markdown]
# ##Transformando o Nível de Ensino em números crescentes

# %% [markdown]
# *   Estudante - 0
# *   Graduação - 1
# *   Pós - 2
# *   Mest - 3
# *   Dout - 4

# %%
df['Nível de Ensino'] = df['Nível de Ensino'].replace({'Estudante de Graduação': 0, 'Graduação/Bacharelado': 1, 'Pós-graduação': 2, 'Mestrado': 3, 'Doutorado ou Phd': 4})
# Out:
# <ipython-input-11-c8c2a0ce5d0f>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Nível de Ensino'] = df['Nível de Ensino'].replace({'Estudante de Graduação': 0, 'Graduação/Bacharelado': 1, 'Pós-graduação': 2, 'Mestrado': 3, 'Doutorado ou Phd': 4})

# %% [markdown]
# ## Transformando o Nível em números crescentes
#
#
# *   Junior - 0
# *   Pleno - 1
# *   Senior - 2

# %%
df['Nível'] = df['Nível'].replace({'Júnior': 0, 'Pleno': 1, 'Sênior': 2})
# Out:
# <ipython-input-12-1a3441c70546>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Nível'] = df['Nível'].replace({'Júnior': 0, 'Pleno': 1, 'Sênior': 2})

# %%
df
# Out:
#         Id  Idade  Faixa idade  Gênero  Cor/raca/etnia  PCD  Vive no Brasil  \
# 0        0     31            3       0               1    0               1
# 1        1     30            3       0               1    0               1
# 2        2     37            4       1               0    0               1
# 3        3     34            3       0               1    0               1
# 4        4     30            3       0               1    0               1
# ...    ...    ...          ...     ...             ...  ...             ...
# 2902  2902     36            4       1               4    0               1
# 2903  2903     23            1       0               4    0               1
# 2904  2904     27            2       1               4    0               1
# 2905  2905     28            2       0               1    0               1
# 2906  2906     32            3       0               1    0               1
#
#       UF onde mora  Nível de Ensino  Área de Formação  Setor  Cargo Atual  \
# 0                9                4                 2      4            3
# 1                6                1                 2      4            0
# 2               23                1                 2      4            1
# 3                9                4                 3      8            1
# 4               17                0                 2     16            6
# ...            ...              ...               ...    ...          ...
# 2902            23                2                 3     19            1
# 2903             7                1                 2     18            1
# 2904             6                1                 7     18            5
# 2905            23                1                 8      4            3
# 2906            18                1                 7      8            7
#
#       Nível  Faixa salarial  \
# 0         2               4
# 1         1              12
# 2         0              12
# 3         0              11
# 4         1              13
# ...     ...             ...
# 2902      1              12
# 2903      0               9
# 2904      1              13
# 2905      0              13
# 2906      1              13
#
#       Quanto tempo de experiência na área de dados você tem?  \
# 0                                                     4
# 1                                                     4
# 2                                                     3
# 3                                                     1
# 4                                                     3
# ...                                                 ...
# 2902                                                  4
# 2903                                                  1
# 2904                                                  4
# 2905                                                  3
# 2906                                                  5
#
#       Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                                     2
# 1                                                     4
# 2                                                     1
# 3                                                     1
# 4                                                     2
# ...                                                 ...
# 2902                                                  2
# 2903                                                  4
# 2904                                                  2
# 2905                                                  2
# 2906                                                  2
#
#       Existe faculdade no Estado
# 0                              1
# 1                              0
# 2                              1
# 3                              1
# 4                              0
# ...                          ...
# 2902                           1
# 2903                           0
# 2904                           0
# 2905                           1
# 2906                           0
#
# [2907 rows x 17 columns]

# %%
df.dtypes
# Out:
# Id                                                                                                                           int64
# Idade                                                                                                                        int64
# Faixa idade                                                                                                                  int64
# Gênero                                                                                                                       int64
# Cor/raca/etnia                                                                                                               int64
# PCD                                                                                                                          int64
# Vive no Brasil                                                                                                               int64
# UF onde mora                                                                                                                 int64
# Nível de Ensino                                                                                                              int64
# Área de Formação                                                                                                             int64
# Setor                                                                                                                        int64
# Cargo Atual                                                                                                                  int64
# Nível                                                                                                                        int64
# Faixa salarial                                                                                                               int64
# Quanto tempo de experiência na área de dados você tem?                                                                       int64
# Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?    int64
# Existe faculdade no Estado                                                                                                   int64
# dtype: object

# %% [markdown]
# ## Separação em X e Y

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(df.drop(columns=['Nível']), df['Nível'], test_size=0.25, random_state=42)

modelo = DecisionTreeClassifier(criterion='gini', max_depth=5)
modelo.fit(X_treino, y_treino)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
previsoes = modelo.predict(X_teste)

# %% [markdown]
# ## Precisao

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report # type: ignore
accuracy_score(y_teste,previsoes)
# Out:
# 0.6822558459422283

# %%
from yellowbrick.classifier import ConfusionMatrix # type: ignore
confusion_matrix(y_teste, previsoes)
# Out:
# array([[144,  26,   1],
#        [ 65, 159,  56],
#        [ 10,  73, 193]])

# %% [markdown]
# ## Visualização de Acertos
#
#
#
# *   0 = Junior
# *   1 = Pleno
# *   2 = Senior

# %%
cm = ConfusionMatrix(modelo)
cm.fit(X_treino, y_treino)
cm.score(X_teste, y_teste)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0.6822558459422283

# %% [markdown]
# ## Precision

# %%
print(classification_report(y_teste, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.84      0.74       171
#            1       0.62      0.57      0.59       280
#            2       0.77      0.70      0.73       276
#
#     accuracy                           0.68       727
#    macro avg       0.68      0.70      0.69       727
# weighted avg       0.69      0.68      0.68       727

# %%
from sklearn import tree
import matplotlib.pyplot as plt
previsores = df.columns
figura, eixos = plt.subplots(nrows=1, ncols=1, figsize=(48,40))
tree.plot_tree(modelo, feature_names=previsores, class_names = ['0', '1', '2'], filled=True);
plt.savefig("modelo_arvore.png", dpi=600)
