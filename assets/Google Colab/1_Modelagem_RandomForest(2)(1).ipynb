# %% [markdown]
# # Importar as bibliotecas e funções

# %%
import sklearn as sk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report # type: ignore
from sklearn import tree
from yellowbrick.classifier import ConfusionMatrix # type: ignore
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Ler a base

# %%
df = pd.read_csv('Filtragem.csv')
df
# Out:
#                                     Id  Idade  Faixa idade  Gênero  \
# 0     001b2d1qtli8t9z7oqgdhj001b2d4i0g     31            3       0
# 1     0026aa3fwd78u0026asg7456tfkjg2cs     30            3       0
# 2     00r21rb9pusd1b0v7ew00r21rw3dy69w     37            4       1
# 3     00v0az4g792svil00vn6y1kfm9hq8vy9     34            3       0
# 4     015qqbrh4rr015qje9gvkbsb7ti1n5df     30            3       0
# ...                                ...    ...          ...     ...
# 2902  zwm2c16e32000c6iaswzwm2c1jv6swo0     36            4       1
# 2903  zws1zie6ro3he9ln337yufzws1zyj7nw     23            1       0
# 2904  zxvrsh0xk8z95k76e63zxvrshjgyigq0     27            2       1
# 2905  zy7hsey7pigk6d4a4zy7hsm7bh1vcozc     28            2       0
# 2906  zyppgxzxko25qkgwsbrgpzyppgxzxs81     32            3       0
#
#       Cor/raca/etnia  PCD  Vive no Brasil          Estado onde mora  \
# 0                  1    0               1         Minas Gerais (MG)
# 1                  1    0               1       Espírito Santo (ES)
# 2                  0    0               1            São Paulo (SP)
# 3                  1    0               1         Minas Gerais (MG)
# 4                  1    0               1       Rio de Janeiro (RJ)
# ...              ...  ...             ...                       ...
# 2902               4    0               1            São Paulo (SP)
# 2903               4    0               1                Goiás (GO)
# 2904               4    0               1       Espírito Santo (ES)
# 2905               1    0               1            São Paulo (SP)
# 2906               1    0               1  Rio Grande do Norte (RN)
#
#       UF onde mora Região onde Mora  ...  \
# 0                9          Sudeste  ...
# 1                6          Sudeste  ...
# 2               23          Sudeste  ...
# 3                9          Sudeste  ...
# 4               17          Sudeste  ...
# ...            ...              ...  ...
# 2902            23          Sudeste  ...
# 2903             7     Centro-oeste  ...
# 2904             6          Sudeste  ...
# 2905            23          Sudeste  ...
# 2906            18         Nordeste  ...
#
#       Qual sua situação atual de trabalho?  Setor Numero de Funcionários  \
# 0                          Empregado (CLT)      4         Acima de 3.000
# 1         Empreendedor ou Empregado (CNPJ)      4           de 101 a 500
# 2                          Empregado (CLT)      4         Acima de 3.000
# 3         Empreendedor ou Empregado (CNPJ)      8           de 101 a 500
# 4         Empreendedor ou Empregado (CNPJ)     16            de 51 a 100
# ...                                    ...    ...                    ...
# 2902                       Empregado (CLT)     19           de 101 a 500
# 2903                       Empregado (CLT)     18            de 51 a 100
# 2904                       Empregado (CLT)     18         Acima de 3.000
# 2905                       Empregado (CLT)      4         de 501 a 1.000
# 2906                       Empregado (CLT)      8         Acima de 3.000
#
#       Cargo Atual Nível  Faixa salarial  \
# 0               3     2               4
# 1               0     1              12
# 2               1     0              12
# 3               1     0              11
# 4               6     1              13
# ...           ...   ...             ...
# 2902            1     1              12
# 2903            1     0               9
# 2904            5     1              13
# 2905            3     0              13
# 2906            7     1              13
#
#       Quanto tempo de experiência na área de dados você tem?  \
# 0                                                     4
# 1                                                     4
# 2                                                     3
# 3                                                     1
# 4                                                     3
# ...                                                 ...
# 2902                                                  4
# 2903                                                  1
# 2904                                                  4
# 2905                                                  3
# 2906                                                  5
#
#       Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                                     2
# 1                                                     4
# 2                                                     1
# 3                                                     1
# 4                                                     2
# ...                                                 ...
# 2902                                                  2
# 2903                                                  4
# 2904                                                  2
# 2905                                                  2
# 2906                                                  2
#
#       Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 2902                                                  0
# 2903                                                  0
# 2904                                                  0
# 2905                                                  0
# 2906                                                  0
#
#       Existe faculdade no Estado
# 0                              1
# 1                              0
# 2                              1
# 3                              1
# 4                              0
# ...                          ...
# 2902                           1
# 2903                           0
# 2904                           0
# 2905                           1
# 2906                           0
#
# [2907 rows x 22 columns]

# %%
df.dtypes
# Out:
# Id                                                                                                                           object
# Idade                                                                                                                         int64
# Faixa idade                                                                                                                   int64
# Gênero                                                                                                                        int64
# Cor/raca/etnia                                                                                                                int64
# PCD                                                                                                                           int64
# Vive no Brasil                                                                                                                int64
# Estado onde mora                                                                                                             object
# UF onde mora                                                                                                                  int64
# Região onde Mora                                                                                                             object
# Nível de Ensino                                                                                                               int64
# Área de Formação                                                                                                              int64
# Qual sua situação atual de trabalho?                                                                                         object
# Setor                                                                                                                         int64
# Numero de Funcionários                                                                                                       object
# Cargo Atual                                                                                                                   int64
# Nível                                                                                                                         int64
# Faixa salarial                                                                                                                int64
# Quanto tempo de experiência na área de dados você tem?                                                                        int64
# Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?     int64
# Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?                                                  int64
# Existe faculdade no Estado                                                                                                    int64
# dtype: object

# %% [markdown]
# ## Retiração das colunas Região e Estado onde mora

# %%
df = df.drop(['Região onde Mora'], axis = 'columns')
df = df.drop(['Estado onde mora'], axis = 'columns')

# %% [markdown]
# ## Dropando coluna inútil

# %%
df = df.drop(['Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?'], axis = 'columns')
df = df.drop(['Numero de Funcionários'], axis = 'columns')
df = df.drop(['Qual sua situação atual de trabalho?'], axis = 'columns')
df = df.drop(['Id'], axis = 'columns')

# %% [markdown]
# ## Transformação dos gêneros em 0s e 1s
#
# Masculino == 0
# Feminino == 1

# %%
df['Gênero'] = df['Gênero'].replace({'Masculino': 0, 'Feminino': 1})
df['Gênero'] = df['Gênero'].replace({'Outro': 0, 'Prefiro não informar': 0})

# %% [markdown]
# ## Transformação dos dados em ordem alfabética

# %%
df['Faixa idade'] = LabelEncoder().fit_transform(df['Faixa idade'])
df['UF onde mora'] = LabelEncoder().fit_transform(df['UF onde mora'])
df['Área de Formação'] = LabelEncoder().fit_transform(df['Área de Formação'])
df['Setor'] = LabelEncoder().fit_transform(df['Setor'])
df['Cargo Atual'] = LabelEncoder().fit_transform(df['Cargo Atual'])
df['Faixa salarial'] = LabelEncoder().fit_transform(df['Faixa salarial'])
df['Quanto tempo de experiência na área de dados você tem?'] = LabelEncoder().fit_transform(df['Quanto tempo de experiência na área de dados você tem?'])
df['Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?'] = LabelEncoder().fit_transform(df['Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?'])
df['Cor/raca/etnia'] = LabelEncoder().fit_transform(df['Cor/raca/etnia'])

# %% [markdown]
# ##Transformando o Nível de Ensino em números crescentes

# %% [markdown]
# *   Estudante - 0
# *   Graduação - 1
# *   Pós - 2
# *   Mest - 3
# *   Dout - 4

# %%
df['Nível de Ensino'] = df['Nível de Ensino'].replace({'Estudante de Graduação': 0, 'Graduação/Bacharelado': 1, 'Pós-graduação': 2, 'Mestrado': 3, 'Doutorado ou Phd': 4})

# %% [markdown]
# ## Transformando o Nível em números crescentes
#
#
# *   Junior - 0
# *   Pleno - 1
# *   Senior - 2

# %%
df['Nível'] = df['Nível'].replace({'Júnior': 0, 'Pleno': 1, 'Sênior': 2})

# %%
df
# Out:
#       Idade  Faixa idade  Gênero  Cor/raca/etnia  PCD  Vive no Brasil  \
# 0        31            3       0               1    0               1
# 1        30            3       0               1    0               1
# 2        37            4       1               0    0               1
# 3        34            3       0               1    0               1
# 4        30            3       0               1    0               1
# ...     ...          ...     ...             ...  ...             ...
# 2902     36            4       1               4    0               1
# 2903     23            1       0               4    0               1
# 2904     27            2       1               4    0               1
# 2905     28            2       0               1    0               1
# 2906     32            3       0               1    0               1
#
#       UF onde mora  Nível de Ensino  Área de Formação  Setor  Cargo Atual  \
# 0                9                4                 2      4            3
# 1                6                1                 2      4            0
# 2               23                1                 2      4            1
# 3                9                4                 3      8            1
# 4               17                0                 2     16            6
# ...            ...              ...               ...    ...          ...
# 2902            23                2                 3     19            1
# 2903             7                1                 2     18            1
# 2904             6                1                 7     18            5
# 2905            23                1                 8      4            3
# 2906            18                1                 7      8            7
#
#       Nível  Faixa salarial  \
# 0         2               4
# 1         1              12
# 2         0              12
# 3         0              11
# 4         1              13
# ...     ...             ...
# 2902      1              12
# 2903      0               9
# 2904      1              13
# 2905      0              13
# 2906      1              13
#
#       Quanto tempo de experiência na área de dados você tem?  \
# 0                                                     4
# 1                                                     4
# 2                                                     3
# 3                                                     1
# 4                                                     3
# ...                                                 ...
# 2902                                                  4
# 2903                                                  1
# 2904                                                  4
# 2905                                                  3
# 2906                                                  5
#
#       Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                                     2
# 1                                                     4
# 2                                                     1
# 3                                                     1
# 4                                                     2
# ...                                                 ...
# 2902                                                  2
# 2903                                                  4
# 2904                                                  2
# 2905                                                  2
# 2906                                                  2
#
#       Existe faculdade no Estado
# 0                              1
# 1                              0
# 2                              1
# 3                              1
# 4                              0
# ...                          ...
# 2902                           1
# 2903                           0
# 2904                           0
# 2905                           1
# 2906                           0
#
# [2907 rows x 16 columns]

# %%
df.dtypes
# Out:
# Idade                                                                                                                        int64
# Faixa idade                                                                                                                  int64
# Gênero                                                                                                                       int64
# Cor/raca/etnia                                                                                                               int64
# PCD                                                                                                                          int64
# Vive no Brasil                                                                                                               int64
# UF onde mora                                                                                                                 int64
# Nível de Ensino                                                                                                              int64
# Área de Formação                                                                                                             int64
# Setor                                                                                                                        int64
# Cargo Atual                                                                                                                  int64
# Nível                                                                                                                        int64
# Faixa salarial                                                                                                               int64
# Quanto tempo de experiência na área de dados você tem?                                                                       int64
# Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?    int64
# Existe faculdade no Estado                                                                                                   int64
# dtype: object

# %% [markdown]
# ## Separação em X e Y

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(df.drop(columns=['Nível']), df['Nível'], test_size=0.25, random_state=42)

modelo = RandomForestClassifier(n_estimators=20,criterion='gini', max_depth=5, random_state=42, ccp_alpha=0.002, min_impurity_decrease=0.001)
modelo.fit(X_treino, y_treino)
# Out:
# RandomForestClassifier(ccp_alpha=0.002, max_depth=5,
#                        min_impurity_decrease=0.001, n_estimators=20,
#                        random_state=42)

# %%
previsoesTeste = modelo.predict(X_teste)
previsoesTreino = modelo.predict(X_treino)

# %% [markdown]
# ## Precisao Treino

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report # type: ignore
accuracy_score(y_treino,previsoesTreino)
# Out:
# 0.7041284403669725

# %% [markdown]
# ## Precisao Teste

# %%
accuracy_score(y_teste,previsoesTeste)
# Out:
# 0.671251719394773

# %% [markdown]
# ## Importance

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import matplotlib.pyplot as plt

# Obtemos a importância das features
importancias = modelo.feature_importances_

# Associamos aos nomes das colunas
df_importancia = pd.DataFrame({
    'Feature': X_treino.columns,
    'Importância': importancias
})

# Ordenamos do mais importante para o menos
df_importancia = df_importancia.sort_values(by='Importância', ascending=False)

# Exibimos
print(df_importancia)
# Out:
#                                               Feature  Importância
# 12  Quanto tempo de experiência na área de dados v...     0.410528
# 11                                     Faixa salarial     0.232194
# 0                                               Idade     0.133460
# 1                                         Faixa idade     0.070967
# 7                                     Nível de Ensino     0.067572
# 13  Quanto tempo de experiência na área de TI/Enge...     0.034186
# 10                                        Cargo Atual     0.018191
# 9                                               Setor     0.009656
# 6                                        UF onde mora     0.008263
# 2                                              Gênero     0.007237
# 8                                    Área de Formação     0.003820
# 14                         Existe faculdade no Estado     0.002604
# 4                                                 PCD     0.000780
# 3                                      Cor/raca/etnia     0.000541
# 5                                      Vive no Brasil     0.000000

# %% [markdown]
# ##Grafico de regras

# %%
# Opcional: plotar em gráfico
plt.figure(figsize=(10, 6))
plt.barh(df_importancia['Feature'], df_importancia['Importância'])
plt.gca().invert_yaxis()
plt.title("Importância das Features")
plt.xlabel("Importância")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Matriz Treino

# %%
from yellowbrick.classifier import ConfusionMatrix
confusion_matrix(y_treino, previsoesTreino)
# Out:
# array([[367, 203,  21],
#        [ 81, 549, 171],
#        [ 10, 159, 619]])

# %% [markdown]
# ## Matriz Teste

# %%
from yellowbrick.classifier import ConfusionMatrix
confusion_matrix(y_teste, previsoesTeste)
# Out:
# array([[103,  60,   8],
#        [ 31, 179,  70],
#        [  3,  67, 206]])

# %% [markdown]
# ## Visualização de Acertos do Teste
#
#
# *   0 = Junior
# *   1 = Pleno
# *   2 = Senior

# %%
cm = ConfusionMatrix(modelo)
cm.fit(X_treino, y_treino)
cm.score(X_treino, y_treino)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0.7041284403669725

# %% [markdown]
# ## Visualização de Acertos do Teste
#
#
#
# *   0 = Junior
# *   1 = Pleno
# *   2 = Senior

# %%
cm = ConfusionMatrix(modelo)
cm.fit(X_treino, y_treino)
cm.score(X_teste, y_teste)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0.671251719394773

# %% [markdown]
# ## Precision Treino

# %%
print(classification_report(y_treino, previsoesTreino))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.62      0.70       591
#            1       0.60      0.69      0.64       801
#            2       0.76      0.79      0.77       788
#
#     accuracy                           0.70      2180
#    macro avg       0.72      0.70      0.71      2180
# weighted avg       0.71      0.70      0.71      2180

# %% [markdown]
# ## Precision Teste

# %%
print(classification_report(y_teste, previsoesTeste))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67       171
#            1       0.58      0.64      0.61       280
#            2       0.73      0.75      0.74       276
#
#     accuracy                           0.67       727
#    macro avg       0.69      0.66      0.67       727
# weighted avg       0.68      0.67      0.67       727

# %%
from sklearn.tree import export_graphviz
import graphviz
from IPython.display import Image, display

# Exporta a árvore para o formato DOT com opções padrão
dot_data = export_graphviz(
    melhor_estimador,
    feature_names=previsores,
    class_names=['0', '1', '2'],
    filled=True,
    rounded=True,
    special_characters=True
)

# Adiciona manualmente atributos globais com alta resolução e espaço ampliado
dot_data_modificado = 'digraph Tree {\n' + \
    'graph [dpi=600, size="80,80!", ratio=compress];\n' + \
    dot_data.split('\n', 1)[1]  # substitui o cabeçalho original

# Gera imagem em PNG de alta qualidade
graph = graphviz.Source(dot_data_modificado)
graph.format = 'png'
output_path = "modelo_arvore_legivel_final"
graph.render(output_path, cleanup=True)

# Exibe o PNG no notebook
display(Image(filename=output_path + ".png"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-5fa8b3663b23> in <cell line: 0>()
#       6 dot_data = export_graphviz(
#       7     #melhor_estimador,
# ----> 8     feature_names=previsores,
#       9     class_names=['0', '1', '2'],
#      10     filled=True,
#
# NameError: name 'previsores' is not defined

# %%
from google.colab import files
df.to_csv('Filtragem_Transformada.csv', index=False)  # Salva o DataFrame modificado
files.download('Filtragem_Transformada.csv')          # Faz o download do arquivo atualizado
